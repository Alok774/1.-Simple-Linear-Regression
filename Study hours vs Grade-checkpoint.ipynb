# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame({'StudyHours':[10,11.5,9,16,9.25,1,11.5,9,8.5,14.5,15.5,13.75,9,8,15],'Grade':[50,50,47,97,49,3,53,42,26,74,82,62,37,15,165]})
df
# Out:
#     StudyHours  Grade
# 0        10.00     50
# 1        11.50     50
# 2         9.00     47
# 3        16.00     97
# 4         9.25     49
# 5         1.00      3
# 6        11.50     53
# 7         9.00     42
# 8         8.50     26
# 9        14.50     74
# 10       15.50     82
# 11       13.75     62
# 12        9.00     37
# 13        8.00     15
# 14       15.00    165

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudyHours  15 non-null     float64
#  1   Grade       15 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 368.0 bytes

# %%
plt.hist(df['Grade'])
plt.xlabel('Grade')
plt.ylabel('Count/Frequncy')
plt.title('Histogram of Grade')
plt.show()

# %%
plt.boxplot(df['Grade'])
plt.title('Boxplot of Grade')
plt.show()

# %%
plt.scatter(df['StudyHours'],df['Grade'],color='red',marker='*',s=30)
plt.show()

# %%
x=df['StudyHours']
y=df['Grade']
plt.scatter(x,y,color='blue',marker='o',s=30)
plt.show()

# %%
plt.plot(df['StudyHours'],df['Grade'])
plt.show()

# %%
plt.plot(df['StudyHours'],color='green',linewidth=3.0)
plt.show()

# %%
x=np.arange(6)
y=x
z=x**2
e=x**3

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,z)

# %%
plt.plot(x,e)

# %%
plt.plot(x,y)
plt.plot(x,z)
plt.plot(x,e)
plt.show()

# %%
plt.plot(x,y,label='x&y')
plt.plot(x,z,label='x&z')
plt.plot(x,e,label='x&e')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5212\3581989977.py in <module>
# ----> 1 plt.plot(x,y,label='x&y')
#       2 plt.plot(x,z,label='x&z')
#       3 plt.plot(x,e,label='x&e')
#       4 plt.legend()
#       5 plt.show()
#
# NameError: name 'x' is not defined

# %%
days=[1,2,3,4,5,6,7]
max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,32]
avg_t=[45,48,48,46,40,42,41]
plt.plot(days,max_t,label='max')
plt.plot(days,min_t,label='min')
plt.plot(days,avg_t,label='average')
plt.xlabel('Day')
plt.ylabel('Temperature')
plt.legend()
plt.show()

# %%
education=['B.Tech','M.Tech','B.Sc','M.Sc']
no_of_students=[50,25,15,10]

# %%
plt.pie(no_of_students,labels=education,autopct='%1.1f%%',explode=[0,0,0.1,0])
plt.show()

# %%
plt.bar(education,no_of_students)
plt.ylabel('no-of-students')
plt.title('Alok students')
plt.show()

# %%
plt.barh(education,no_of_students)
plt.xlabel('no-of-students')
plt.title('Alok students')
plt.show()

# %%
company=['GOOGLE','AMAZON','MSFT','FB']
revenue=[90,136,89,27]
profit=[40,20,34,12]
plt.bar(company,revenue,label='Revenue')
plt.bar(company,profit,label='Profit')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
company=['GOOGLE','AMAZON','MSFT','FB']
revenue=[90,136,89,27]
profit=[40,20,34,12]
xpos=np.arange(len(company))
plt.bar(xpos-0.2,revenue,width=0.4,label='Revenue')
plt.bar(xpos+0.2,profit,width=0.4,label='Profit')
plt.xticks(xpos,company)
plt.ylabel('Revenue(Bin)')
plt.title('US Technology stocks')
plt.legend()
plt.show()

# %%
plt.show()

# %%
plt.subplot(3,2,6)
plt.bar(ecommerce,Q4_Profit)
plt.title('Quarter4 Profit')
# Out:
# Text(0.5, 1.0, 'Quarter4 Profit')
